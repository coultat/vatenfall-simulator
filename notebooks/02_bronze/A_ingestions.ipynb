# %%
# %run /Workspace/Users/felipemkautzmann@gmail.com/vatenfall-simulator/notebooks/02_bronze/ingestion_references

# %%
# %run /Workspace/Users/felipemkautzmann@gmail.com/vatenfall-simulator/notebooks/02_bronze/ingestion_grid_events

# %%
# %run /Workspace/Users/felipemkautzmann@gmail.com/vatenfall-simulator/notebooks/02_bronze/ingestion_market_prices

# %%
# %run /Workspace/Users/felipemkautzmann@gmail.com/vatenfall-simulator/notebooks/02_bronze/ingestion_weather
