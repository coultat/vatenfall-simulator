# %%
# %run /Workspace/Users/felipemkautzmann@gmail.com/vatenfall-simulator/notebooks/03_silver/B_silver_grid_events

# %%
# %run /Workspace/Users/felipemkautzmann@gmail.com/vatenfall-simulator/notebooks/03_silver/B_silver_market_prices

# %%
# %run /Workspace/Users/felipemkautzmann@gmail.com/vatenfall-simulator/notebooks/03_silver/B_silver_references

# %%
# %run /Workspace/Users/felipemkautzmann@gmail.com/vatenfall-simulator/notebooks/03_silver/B_silver_weather
