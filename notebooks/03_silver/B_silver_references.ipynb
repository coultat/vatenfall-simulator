# %%
from src.utils.load_config import paths_config as pc

# %%
# %run /Workspace/Users/felipemkautzmann@gmail.com/vatenfall-simulator/src/transforms/reference_transform

# %%
table_name_asset_reference = pc['tables']['references']['asset_reference']
asset_reference_df = spark.read.table(table_name_asset_reference)
asset_reference_df = standarize_asset_reference(asset_reference_df)
asset_reference_df.write.format('delta').option('overwriteSchema', "true").mode('overwrite').saveAsTable(table_name_asset_reference)

# %%
table_name_event_type_reference = pc['tables']['references']['event_type_reference']
event_type_reference_df = spark.read.table(table_name_event_type_reference)
event_type_reference_df = standarize_event_type_reference(event_type_reference_df)
event_type_reference_df.write.format('delta').option('overwriteSchema', 'true').mode('overwrite').saveAsTable(table_name_event_type_reference)

# %%
table_name_market_reference = pc['tables']['references']['market_reference']
market_reference_df = spark.read.table(table_name_market_reference)
market_reference_df = standarize_market_references(market_reference_df)
market_reference_df.write.format('delta').option('overwriteSchema', 'true').mode('overwrite').saveAsTable(table_name_market_reference)

# %%
table_name_region_reference = pc['tables']['references']['region_reference']
region_reference_df = spark.read.table(table_name_region_reference)
region_reference_df = standarize_region_reference(region_reference_df)
region_reference_df.write.format('delta').option('overwriteSchema', 'true').mode('overwrite').saveAsTable(table_name_region_reference)

# %%
table_name_weather_alert_reference = pc['tables']['references']['weather_alert_reference']
weather_alert_reference_df = spark.read.table(table_name_weather_alert_reference)
weather_alert_reference_df = standarize_weather_alert_reference(weather_alert_reference_df)
weather_alert_reference_df.write.format('delta').option('overwriteSchema', 'true').mode('overwrite').saveAsTable(table_name_weather_alert_reference)
