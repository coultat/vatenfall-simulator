# %%
# %run /Workspace/Users/felipemkautzmann@gmail.com/vatenfall-simulator/notebooks/05_gold/B_daily_market_summary

# %%
# %run /Workspace/Users/felipemkautzmann@gmail.com/vatenfall-simulator/notebooks/05_gold/B_grid_incident_summary

# %%
# %run /Workspace/Users/felipemkautzmann@gmail.com/vatenfall-simulator/notebooks/05_gold/B_weather_impact_summary

# %%
# %run /Workspace/Users/felipemkautzmann@gmail.com/vatenfall-simulator/notebooks/05_gold/B_gold_regional_operations_dashboard
