# %%
from src.utils.load_config import paths_config as pc
import logging

# %%
# %run /Workspace/Users/felipemkautzmann@gmail.com/vatenfall-simulator/src/transforms/gold_daily_market_transform

# %%
silver_market_table_name = pc['tables']['silver']['market_prices']
gold_daily_summary_table_name = pc['tables']['gold']['daily_market_summary']
market_df = spark.read.table(silver_market_table_name)
market_df = get_gold_daily_market_summary(market_df)

# %%
try:
    market_df.write.format('delta').option('overwriteSchema', 'true').mode('overwrite').saveAsTable(gold_daily_summary_table_name)
    logging.info(f"Gold Daily Summary was succesfull saved in the {gold_daily_summary_table_name}")
except Exception as e:
    logging.error(f"Data couldn't be stored in {gold_daily_summary_table_name}")
