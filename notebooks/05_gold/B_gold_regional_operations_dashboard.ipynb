# %%
from src.utils.load_config import paths_config as pc
import logging

# %%
# %run /Workspace/Users/felipemkautzmann@gmail.com/vatenfall-simulator/src/transforms/gold/regional_operations_dashboard_transform

# %%
table_name = pc['tables']['gold']['daily_market_summary']
daily_market_df = spark.read.table(table_name)

table_name = pc['tables']['gold']['grid_incident_summary']
grid_incident_df = spark.read.table(table_name)

table_name = pc['tables']['gold']['weather_impact_summary']
weather_impact_df = spark.read.table(table_name)

# %%
table_to_write = pc['tables']['gold']['regional_operations_dashboard']
regional_operations_dashboard_df = get_gold_regional_operations_dashboard(daily_market_df, grid_incident_df, weather_impact_df)
regional_operations_dashboard_df.write.format('delta').option('overwriteSchema', 'true').mode('overwrite').saveAsTable(table_to_write)
