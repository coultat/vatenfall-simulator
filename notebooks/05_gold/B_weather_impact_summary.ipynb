# %%
from src.utils.load_config import paths_config as pc
import logging

# %%
# %run /Workspace/Users/felipemkautzmann@gmail.com/vatenfall-simulator/src/transforms/gold_weather_impact_transform

# %%
weather_table_name = pc['tables']['silver']['weather']
weather_df = spark.read.table(weather_table_name)

# %%
try:
    gold_weather_impact_df = weather_df.transform(get_gold_weather_impact_summary)
    table_name = pc['tables']['gold']['weather_impact_summary']
    gold_weather_impact_df.write.format('delta').option('overwriteSchema', 'true').mode('overwrite').saveAsTable(table_name)
except KeyError:
    logging.error(f"The table {table} is not in path_config.yaml")
except Exception as e:
    logging.error(f"Data couldn't be stored in {table} because of: {e.args}")
